# %%
# fastai lib for NLP
from fastai.text import *
# Colab library to upload files to notebook
from google.colab import files

# %%
# Install Kaggle library
# !pip install -q kaggle

# %% [markdown]
# ## Download Data

# %%
# Upload kaggle API key file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-35526bed-cdd5-4659-9ad2-b95d84674333" name="files[]" multiple disabled />
#      <output id="result-35526bed-cdd5-4659-9ad2-b95d84674333">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# Move kaggle API key file to the root folder
# !mv kaggle.json /root/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# Downlaod data for the videogamesales
# !kaggle datasets download -d gregorut/videogamesales --unzip
# Out:
# Downloading videogamesales.zip to /content
#   0% 0.00/381k [00:00<?, ?B/s]
# 100% 381k/381k [00:00<00:00, 57.3MB/s]

# %% [markdown]
# ## Pre-processing

# %%
df = pd.read_csv("vgsales.csv")

# %%
df.head(5)
# Out:
#    Rank                      Name Platform  ...  JP_Sales Other_Sales Global_Sales
# 0     1                Wii Sports      Wii  ...      3.77        8.46        82.74
# 1     2         Super Mario Bros.      NES  ...      6.81        0.77        40.24
# 2     3            Mario Kart Wii      Wii  ...      3.79        3.31        35.82
# 3     4         Wii Sports Resort      Wii  ...      3.28        2.96        33.00
# 4     5  Pokemon Red/Pokemon Blue       GB  ...     10.22        1.00        31.37
#
# [5 rows x 11 columns]

# %%
unwanted_cols = ['Rank','Platform','Publisher', 'Year' ,'NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']
df.drop(unwanted_cols, inplace=True, axis=1)

# %%
df.head(5)
# Out:
#                        Name         Genre
# 0                Wii Sports        Sports
# 1         Super Mario Bros.      Platform
# 2            Mario Kart Wii        Racing
# 3         Wii Sports Resort        Sports
# 4  Pokemon Red/Pokemon Blue  Role-Playing

# %%
path = ""
target_col = 'Genre'
input_col = ['Name']
train_df = df.iloc[0:12000]
valid_df = df.iloc[12000:16000]

# %% [markdown]
# ## Language Model

# %%
data_lm = TextLMDataBunch.from_df(path=path,
                                  text_cols=input_col,
                                  label_cols=target_col,
                                  train_df=train_df,
                                  valid_df=valid_df)

# %%
data_lm.show_batch(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>idx</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>xxmaj nintendogs xxbos xxmaj mario xxmaj kart xxup ds xxbos xxmaj pokemon xxmaj gold / xxmaj pokemon xxmaj silver xxbos xxmaj wii xxmaj fit xxbos xxmaj wii xxmaj fit xxmaj plus xxbos xxmaj kinect xxmaj adventures ! xxbos xxmaj grand xxmaj theft xxmaj auto v xxbos xxmaj grand xxmaj theft xxmaj auto : xxmaj san xxmaj andreas xxbos xxmaj super xxmaj mario xxmaj world xxbos xxmaj brain xxmaj age :</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>xxbos xxmaj fallout 3 xxbos xxmaj pokemon xxmaj mystery xxmaj dungeon : xxmaj explorers of xxmaj time / xxmaj explorers of xxmaj darkness xxbos xxmaj uncharted : xxmaj drake 's xxmaj fortune xxbos xxmaj madden xxup nfl 06 xxbos xxup lego xxmaj star xxmaj wars : xxmaj the xxmaj complete xxmaj saga xxbos xxmaj diddy xxmaj kong xxmaj racing xxbos xxmaj monster xxmaj hunter xxmaj freedom 3 xxbos xxmaj dr.</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>creed xxup iv : xxmaj black xxmaj flag xxbos xxmaj english xxmaj training : xxmaj have xxmaj fun xxmaj xxunk xxmaj your xxmaj xxunk ! xxbos xxmaj james xxmaj bond 007 : xxmaj nightfire xxbos xxmaj ratchet &amp; xxmaj clank xxbos xxmaj mario xxmaj party 9 xxbos xxmaj star xxmaj wars xxmaj episode xxup iii : xxmaj revenge of the xxmaj sith xxbos xxmaj max xxmaj payne xxbos xxmaj the</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>xxmaj invaders xxbos xxmaj crazy xxmaj taxi xxbos xxmaj perfect xxmaj dark xxbos xxmaj game xxmaj party xxbos xxmaj dragon xxmaj warrior xxbos xxmaj tomb xxmaj raider ( 2013 ) xxbos xxmaj marvel : xxmaj ultimate xxmaj alliance xxbos xxup pes 2009 : xxmaj pro xxmaj evolution xxmaj soccer xxbos xxmaj mario xxmaj party 2 xxbos xxmaj saints xxmaj row : xxmaj the xxmaj third xxbos xxmaj rockstar xxmaj games</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>airborne xxmaj commando xxbos xxmaj kingdom xxmaj hearts : xxmaj birth by xxmaj sleep xxbos xxup ufc 2009 xxmaj undisputed xxbos xxmaj dark xxmaj souls xxbos xxmaj yu - xxmaj gi - xxmaj oh ! xxmaj the xxmaj eternal xxmaj duelist xxmaj soul xxbos xxmaj need for xxmaj speed : prostreet xxbos xxmaj the xxmaj sims 3 xxbos xxmaj tom xxmaj clancy 's xxmaj splinter xxmaj cell : xxmaj conviction</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn = language_model_learner(data_lm, AWD_LSTM, drop_mult=0.5)
learn.fit_one_cycle(1, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.701308</td>
#       <td>3.005414</td>
#       <td>0.472396</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()
learn.fit_one_cycle(1, 1e-3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.120106</td>
#       <td>1.636049</td>
#       <td>0.457250</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.predict("Dragon ", n_words=7)
# Out:
# 'Dragon  Ball : Dora Zero'

# %%
# Save the encoder
learn.save_encoder('ft_enc')

# %% [markdown]
# ## Classifier

# %%
data_class = TextClasDataBunch.from_df(path=path,
                                       train_df= train_df,
                                       valid_df=valid_df,
                                       label_cols=target_col,
                                       text_cols=input_col,
                                       vocab=data_lm.train_ds.vocab)

# %%
learn = text_classifier_learner(data_class, AWD_LSTM, drop_mult=0.5)
learn.load_encoder('ft_enc')

# %%
data_class.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>text</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>xxbos xxup ds xxmaj xxunk xxmaj xxunk xxmaj suspense : xxmaj xxunk xxmaj xxunk - xxmaj xxunk xxmaj xxunk - xxmaj xxunk xxmaj xxunk xxmaj xxunk - xxmaj koto ni xxmaj maru xxmaj xxunk xxmaj xxunk : xxmaj kyoto xxmaj xxunk xxmaj xxunk xxmaj file</td>
#       <td>Adventure</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj xxunk xxmaj daigaku xxmaj xxunk xxmaj xxunk xxmaj xxunk - xxmaj kawashima xxmaj ryuuta xxmaj kyouju xxmaj kanshuu - xxmaj mono xxmaj xxunk xxmaj nou o xxmaj xxunk xxunk no xxmaj oni xxmaj training</td>
#       <td>Action</td>
#     </tr>
#     <tr>
#       <td>xxbos xxup ds xxmaj xxunk xxmaj xxunk xxmaj suspense xxmaj shin xxmaj tantei xxmaj series : xxmaj kyoto xxmaj xxunk xxmaj xxunk no xxmaj xxunk - xxmaj xxunk no xxmaj wana</td>
#       <td>Adventure</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj johnny xxmaj bravo in xxmaj the xxmaj xxunk - xxmaj mega - xxmaj mighty - xxmaj ultra - xxmaj extreme xxmaj date - o - xxmaj rama</td>
#       <td>Action</td>
#     </tr>
#     <tr>
#       <td>xxbos xxmaj dragon xxmaj quest 25 xxmaj xxunk xxmaj xxunk : xxmaj famicom &amp; xxmaj super xxmaj famicom xxmaj dragon xxmaj quest i - xxup ii - xxup iii</td>
#       <td>Role-Playing</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(1, 1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.849294</td>
#       <td>1.986713</td>
#       <td>0.319000</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.freeze_to(-2)
learn.fit_one_cycle(1, slice(5e-3/2., 5e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.671223</td>
#       <td>1.900727</td>
#       <td>0.354250</td>
#       <td>00:08</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.unfreeze()
learn.fit_one_cycle(1, slice(2e-3/100, 2e-3))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.422830</td>
#       <td>1.797472</td>
#       <td>0.397750</td>
#       <td>00:15</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.predict("Genital Jousting")
# Out:
# (Category Action,
#  tensor(0),
#  tensor([0.1625, 0.0817, 0.0283, 0.1539, 0.0572, 0.0750, 0.0654, 0.1193, 0.0659,
#          0.0779, 0.0700, 0.0428]))
